# %%
#Import libaries required
import numpy as np
import pandas as pd

# %%
#Load in dataset ('Dataset_01.csv')
df = pd.read_csv('C:\\Users\mmmig\\OneDrive - University of Plymouth\\MSc 2023-2024\\Machine Learning and Artificial intelligence for Healthcare (MATH516)\\Untitled Folder\\Dataset _01.csv')
print(df)
# Out:
#                     Subjects  Grade  original_firstorder_Skewness_t1c  \
# 0   Meningioma-SEG-CLASS-001      1                         -0.202380
# 1   Meningioma-SEG-CLASS-002      1                          0.078198
# 2   Meningioma-SEG-CLASS-003      0                         -1.122465
# 3   Meningioma-SEG-CLASS-004      0                         -0.559125
# 4   Meningioma-SEG-CLASS-005      0                         -0.854174
# ..                       ...    ...                               ...
# 89  Meningioma-SEG-CLASS-091      0                         -1.325915
# 90  Meningioma-SEG-CLASS-092      1                         -0.114564
# 91  Meningioma-SEG-CLASS-093      0                         -0.266299
# 92  Meningioma-SEG-CLASS-095      1                         -0.163404
# 93  Meningioma-SEG-CLASS-096      1                         -0.141390
#
#     original_glrlm_HighGrayLevelRunEmphasis_t1c  \
# 0                                      1.000000
# ...

# %%
# Inspect dataset
#Inspecting the number of enteries and features
print(str("the dataset has ") + str(df.shape[0]) + str(' entries and ') + str(df.shape[1]) + str(' features'))

#Inspect Dataset
df
# Out:
# the dataset has 94 entries and 50 features
#                     Subjects  Grade  original_firstorder_Skewness_t1c  \
# 0   Meningioma-SEG-CLASS-001      1                         -0.202380
# 1   Meningioma-SEG-CLASS-002      1                          0.078198
# 2   Meningioma-SEG-CLASS-003      0                         -1.122465
# 3   Meningioma-SEG-CLASS-004      0                         -0.559125
# 4   Meningioma-SEG-CLASS-005      0                         -0.854174
# ..                       ...    ...                               ...
# 89  Meningioma-SEG-CLASS-091      0                         -1.325915
# 90  Meningioma-SEG-CLASS-092      1                         -0.114564
# 91  Meningioma-SEG-CLASS-093      0                         -0.266299
# 92  Meningioma-SEG-CLASS-095      1                         -0.163404
# 93  Meningioma-SEG-CLASS-096      1                         -0.141390
#
#     original_glrlm_HighGrayLevelRunEmphasis_t1c  \
# ...

# %%
#Inspect Feature Names and list them
list(df.columns)
# Out:
# ['Subjects',
#  'Grade',
#  'original_firstorder_Skewness_t1c',
#  'original_glrlm_HighGrayLevelRunEmphasis_t1c',
#  'wavelet-LLH_glszm_GrayLevelNonUniformityNormalized_t1c',
#  'wavelet-LHL_glszm_GrayLevelNonUniformityNormalized_t1c',
#  'wavelet-HLL_glszm_GrayLevelNonUniformityNormalized_t1c',
#  'wavelet-HLH_firstorder_Mean_t1c',
#  'wavelet-HLH_glszm_ZoneEntropy_t1c',
#  'wavelet-HHL_glszm_HighGrayLevelZoneEmphasis_t1c',
#  'wavelet-HHH_firstorder_Skewness_t1c',
#  'wavelet-HHH_glszm_SizeZoneNonUniformityNormalized_t1c',
#  'original_glszm_HighGrayLevelZoneEmphasis_t2f',
#  'wavelet-LHH_glszm_GrayLevelNonUniformityNormalized_t2f',
#  'wavelet-LHH_glszm_SizeZoneNonUniformityNormalized_t2f',
#  'wavelet-LHH_glszm_SmallAreaHighGrayLevelEmphasis_t2f',
#  'wavelet-HLL_glrlm_RunVariance_t2f',
#  'wavelet-HLH_glszm_GrayLevelNonUniformityNormalized_t2f',
#  'wavelet-HLH_glszm_SizeZoneNonUniformityNormalized_t2f',
#  'wavelet-HHL_glszm_SmallAreaLowGrayLevelEmphasis_t2f',
# ...

# %%
#Clean data
#Check for missing values for each feature
df.isna().sum()
# No missing values found for any feature
# therefore no features were dropped due to missing values
# Out:
# Subjects                                                  0
# Grade                                                     0
# original_firstorder_Skewness_t1c                          0
# original_glrlm_HighGrayLevelRunEmphasis_t1c               0
# wavelet-LLH_glszm_GrayLevelNonUniformityNormalized_t1c    0
# wavelet-LHL_glszm_GrayLevelNonUniformityNormalized_t1c    0
# wavelet-HLL_glszm_GrayLevelNonUniformityNormalized_t1c    0
# wavelet-HLH_firstorder_Mean_t1c                           0
# wavelet-HLH_glszm_ZoneEntropy_t1c                         0
# wavelet-HHL_glszm_HighGrayLevelZoneEmphasis_t1c           0
# wavelet-HHH_firstorder_Skewness_t1c                       0
# wavelet-HHH_glszm_SizeZoneNonUniformityNormalized_t1c     0
# original_glszm_HighGrayLevelZoneEmphasis_t2f              0
# wavelet-LHH_glszm_GrayLevelNonUniformityNormalized_t2f    0
# wavelet-LHH_glszm_SizeZoneNonUniformityNormalized_t2f     0
# wavelet-LHH_glszm_SmallAreaHighGrayLevelEmphasis_t2f      0
# ...

# %%
#Drop features with missing data?
#No missing data

# %%
#Data manipulation
#Percentage missingness- Drop features depending on %. above 0.5%? 
# Count the number of available values for each column
num_samples = df.count().values
num_missing = df.isna().sum()
perct_missing=(num_missing/num_samples)*100

# create a dataFrame of percentage missingness
perc_missing=pd.DataFrame({'feature':df.columns, 'perct_missing':perct_missing}).reset_index().drop(columns=['index'])
perc_missing

#No missing data therefore all features have 0% missingness
# Out:
#                                               feature  perct_missing
# 0                                            Subjects            0.0
# 1                                               Grade            0.0
# 2                    original_firstorder_Skewness_t1c            0.0
# 3         original_glrlm_HighGrayLevelRunEmphasis_t1c            0.0
# 4   wavelet-LLH_glszm_GrayLevelNonUniformityNormal...            0.0
# 5   wavelet-LHL_glszm_GrayLevelNonUniformityNormal...            0.0
# 6   wavelet-HLL_glszm_GrayLevelNonUniformityNormal...            0.0
# 7                     wavelet-HLH_firstorder_Mean_t1c            0.0
# 8                   wavelet-HLH_glszm_ZoneEntropy_t1c            0.0
# 9     wavelet-HHL_glszm_HighGrayLevelZoneEmphasis_t1c            0.0
# 10                wavelet-HHH_firstorder_Skewness_t1c            0.0
# 11  wavelet-HHH_glszm_SizeZoneNonUniformityNormali...            0.0
# 12       original_glszm_HighGrayLevelZoneEmphasis_t2f            0.0
# ...

# %%
#Filter data- using PANDAS#
#
#Not Required at this stage

# %%
#Pre Processing
#Data Splitting-  Split into test and training data. 
#Scale training data- Reduces dominance 


#Import data splitting library
from sklearn.model_selection import train_test_split

# split dataset into data and labels 
X,y=df.drop(columns=['Subjects', 'Grade']), df[['Subjects', 'Grade']]


# split data into train and test set 70% training and 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state= 1)

# %%
#Confirm splitting
print(X.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (94, 48) (65, 48) (29, 48) (65, 2) (29, 2)

# %%
# Import preprocessing library
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# we only aply the feature scaling on the features other than dummy variables.
X_train_sc = sc.fit_transform(X_train)

# %%
# Confirm scaling of the train data
pd.DataFrame(X_train_sc, columns=[X.columns])
# Out:
#    original_firstorder_Skewness_t1c  \
# 0                          0.115560
# 1                         -0.529465
# 2                         -0.235735
# 3                          0.459137
# 4                          0.273058
# ..                              ...
# 60                         1.551819
# 61                        -0.805380
# 62                        -0.526406
# 63                         1.499506
# 64                        -1.168525
#
#    original_glrlm_HighGrayLevelRunEmphasis_t1c  \
# 0                                     0.675466
# 1                                     0.801952
# 2                                    -1.264052
# 3                                     0.531471
# 4                                     0.808102
# ..                                         ...
# 60                                    0.806336
# 61                                   -1.264052
# 62                                    0.794988
# ...

# %%
#Exploratory data analysis 
#Descriptive statistics using describe function
#Log fold changes?
# Generate descriptive statistics 
df.describe()
# Out:
#            Grade  original_firstorder_Skewness_t1c  \
# count  94.000000                         94.000000
# mean    0.436170                         -0.243500
# std     0.498568                          0.768804
# min     0.000000                         -2.052332
# 25%     0.000000                         -0.774200
# 50%     0.000000                         -0.243948
# 75%     1.000000                          0.178430
# max     1.000000                          2.244620
#
#        original_glrlm_HighGrayLevelRunEmphasis_t1c  \
# count                                    94.000000
# mean                                      2.899225
# std                                       1.438076
# min                                       1.000000
# 25%                                       1.000000
# 50%                                       3.972175
# 75%                                       3.994126
# max                                       3.999413
#
# ...

# %%
# Transpose for ease of presentation
stats_dataset= df.describe().T
stats_dataset.head(10)
# Out:
#                                                     count      mean       std  \
# Grade                                                94.0  0.436170  0.498568
# original_firstorder_Skewness_t1c                     94.0 -0.243500  0.768804
# original_glrlm_HighGrayLevelRunEmphasis_t1c          94.0  2.899225  1.438076
# wavelet-LLH_glszm_GrayLevelNonUniformityNormali...   94.0  0.635435  0.115019
# wavelet-LHL_glszm_GrayLevelNonUniformityNormali...   94.0  0.623576  0.107621
# wavelet-HLL_glszm_GrayLevelNonUniformityNormali...   94.0  0.632099  0.103743
# wavelet-HLH_firstorder_Mean_t1c                      94.0  0.002783  0.007713
# wavelet-HLH_glszm_ZoneEntropy_t1c                    94.0  2.236178  0.622811
# wavelet-HHL_glszm_HighGrayLevelZoneEmphasis_t1c      94.0  2.489702  0.411192
# wavelet-HHH_firstorder_Skewness_t1c                  94.0 -0.065559  0.123249
#
#                                                          min       25%  \
# ...

# %%
#Statistical Differences based on Grade
'''
    get stats for Normal
'''
negative=df[df['Grade']==0].describe().T
negative.head(5)
# Out:
#                                                     count      mean       std  \
# Grade                                                53.0  0.000000  0.000000
# original_firstorder_Skewness_t1c                     53.0 -0.448213  0.724097
# original_glrlm_HighGrayLevelRunEmphasis_t1c          53.0  2.454095  1.497112
# wavelet-LLH_glszm_GrayLevelNonUniformityNormali...   53.0  0.612897  0.104099
# wavelet-LHL_glszm_GrayLevelNonUniformityNormali...   53.0  0.608909  0.106083
#
#                                                          min       25%  \
# Grade                                               0.000000  0.000000
# original_firstorder_Skewness_t1c                   -2.052332 -0.932368
# original_glrlm_HighGrayLevelRunEmphasis_t1c         1.000000  1.000000
# wavelet-LLH_glszm_GrayLevelNonUniformityNormali...  0.500000  0.520000
# wavelet-LHL_glszm_GrayLevelNonUniformityNormali...  0.500000  0.520000
#
# ...

# %%
'''
    get stats for Positive 1
'''
positive=df[df['Grade']==1].describe().T
positive.head(5)
# Out:
#                                                     count      mean       std  \
# Grade                                                41.0  1.000000  0.000000
# original_firstorder_Skewness_t1c                     41.0  0.021129  0.751861
# original_glrlm_HighGrayLevelRunEmphasis_t1c          41.0  3.474637  1.136918
# wavelet-LLH_glszm_GrayLevelNonUniformityNormali...   41.0  0.664569  0.122995
# wavelet-LHL_glszm_GrayLevelNonUniformityNormali...   41.0  0.642535  0.107916
#
#                                                          min       25%  \
# Grade                                               1.000000  1.000000
# original_firstorder_Skewness_t1c                   -1.572566 -0.469204
# original_glrlm_HighGrayLevelRunEmphasis_t1c         1.000000  3.951451
# wavelet-LLH_glszm_GrayLevelNonUniformityNormali...  0.500000  0.573964
# wavelet-LHL_glszm_GrayLevelNonUniformityNormali...  0.505000  0.555556
#
# ...

# %%
#Compare Statistics
feat_means=pd.DataFrame({'negative':negative[:-1]['mean'], 'positive':positive[:-1]['mean']})

# calculate fold changes and add to dataframe
fc=(feat_means.positive - feat_means.negative)/feat_means.negative
feat_means['fc']=fc

# calculate Log2 of fold change and add to data frame
log2_fc=np.log2(np.abs(fc))
feat_means['log2_fc']=log2_fc
feat_means=feat_means.reset_index().rename(columns={'index':'feature'})

# sort dataframe according to fold change
feat_means['abs']=abs(feat_means['fc'])

# Sort by fold absolute change
feat_means=feat_means.sort_values(by=['abs'],ascending=False).drop(columns=['abs'])
feat_means.head(10)
# Out:
#                                               feature      negative  \
# 0                                               Grade  0.000000e+00
# 6                     wavelet-HLH_firstorder_Mean_t1c  1.028665e-03
# 9                 wavelet-HHH_firstorder_Skewness_t1c -2.655564e-02
# 1                    original_firstorder_Skewness_t1c -4.482127e-01
# 19                wavelet-LLL_firstorder_Skewness_t1c -4.445601e-01
# 26                    original_glszm_ZoneVariance_t1c  2.029187e+08
# 24               original_glszm_GrayLevelVariance_t1c  8.396697e-02
# 38                    original_glszm_ZoneVariance_t2f  6.076923e+08
# 25  original_gldm_SmallDependenceLowGrayLevelEmpha...  1.742806e-03
# 2         original_glrlm_HighGrayLevelRunEmphasis_t1c  2.454095e+00
#
#         positive        fc   log2_fc
# 0   1.000000e+00       inf       inf
# 6   5.050111e-03  3.909383  1.966941
# 9  -1.159781e-01  3.367363  1.751619
# 1   2.112889e-02 -1.047140  0.066455
# ...

# %%
#Import library 
import matplotlib.pyplot as plt
'''
    plot fold changes (elevation or reduction)
    in vals betweennegative and positive subjects
'''
plt.figure(figsize=(18,6))
plt.bar(feat_means['feature'],feat_means['fc'], color ='blue',width = 0.4)
plt.xticks(feat_means['feature'], rotation ='vertical')
plt.xlabel('Feature')
plt.ylabel('Log2 Fold change')
plt.tight_layout()

# %%
#Boxplots and symmetry errors?
#List features
features=df.drop(columns=['Subjects', 'Grade']).columns
features
# Out:
# Index(['original_firstorder_Skewness_t1c',
#        'original_glrlm_HighGrayLevelRunEmphasis_t1c',
#        'wavelet-LLH_glszm_GrayLevelNonUniformityNormalized_t1c',
#        'wavelet-LHL_glszm_GrayLevelNonUniformityNormalized_t1c',
#        'wavelet-HLL_glszm_GrayLevelNonUniformityNormalized_t1c',
#        'wavelet-HLH_firstorder_Mean_t1c', 'wavelet-HLH_glszm_ZoneEntropy_t1c',
#        'wavelet-HHL_glszm_HighGrayLevelZoneEmphasis_t1c',
#        'wavelet-HHH_firstorder_Skewness_t1c',
#        'wavelet-HHH_glszm_SizeZoneNonUniformityNormalized_t1c',
#        'original_glszm_HighGrayLevelZoneEmphasis_t2f',
#        'wavelet-LHH_glszm_GrayLevelNonUniformityNormalized_t2f',
#        'wavelet-LHH_glszm_SizeZoneNonUniformityNormalized_t2f',
#        'wavelet-LHH_glszm_SmallAreaHighGrayLevelEmphasis_t2f',
#        'wavelet-HLL_glrlm_RunVariance_t2f',
#        'wavelet-HLH_glszm_GrayLevelNonUniformityNormalized_t2f',
#        'wavelet-HLH_glszm_SizeZoneNonUniformityNormalized_t2f',
# ...

# %%
#Import library
import seaborn as sns
#ApoE
sns.boxplot(x = df['Grade'],y = df[features[0]])
# Out:
# <Axes: xlabel='Grade', ylabel='original_firstorder_Skewness_t1c'>

# %%
for feature in features:
    sns.boxplot(x=df['Grade'], y=df[feature])
    plt.title(f'Boxplot of {feature} against Grade')
    plt.xlabel('Grade')
    plt.ylabel(feature)
    plt.show()

# %%
#Augementation for class imblance e.g SMOTE
#Accuracy on test data

target_count = df['Grade'].value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])

# Plot result
df['Grade'].value_counts().plot(kind='bar', title='Count (Grade)');

#Slight class imbalance
# Out:
# Class 0: 53
# Class 1: 41

# %%
#Plot the Confusion Matrix to visualise the performance of the classifier
